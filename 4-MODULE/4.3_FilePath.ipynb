# %%
##Create new Directory
import os
cwd = os.getcwd()  # Get current working directory
print("Current Working Directory:", cwd)
# Out:
# Current Working Directory: f:\PYTHON_AI\4-MODULE

# %%
##Create new Directory
import os
new_directory = os.path.join(cwd, 'newFile_directory')
if not os.path.exists(new_directory):
    os.makedirs(new_directory)
    print(f"Directory '{new_directory}' created.")
# Out:
# Directory 'f:\PYTHON_AI\4-MODULE\newFile_directory' created.

# %%
## Listing files in a directory
files = os.listdir(cwd)
print("Files in the current directory:")
for file in files:
    print(file)
# Out:
# Files in the current directory:
# 4.1-import.ipynb
# 4.2_Libraries.ipynb
# 4.3_FilePath.ipynb
# destination.txt
# example.csv
# example.txt
# newFile_directory
# new_directory
# package

# %%
### Joining paths

path = os.path.join(cwd, 'newFile_directory')
print("Joined Path:", path)
# Out:
# Joined Path: f:\PYTHON_AI\4-MODULE\newFile_directory
