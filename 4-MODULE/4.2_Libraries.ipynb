# %%
import array

arr = array.array('i', [1, 2, 3, 4, 5])
print(arr)
# Out:
# array('i', [1, 2, 3, 4, 5])

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
import random
print(random.randint(1, 10))
print(random.choice(['apple', 'banana', 'cherry']))
# Out:
# 2
# apple

# %%
import os 
print(os.getcwd())  # Get the current working directory
os.mkdir('new_directory')  # Create a new directory
# Out:
# f:\PYTHON_AI\4-MODULE

# %%
### High level operations with files and directories
import shutil
shutil.copy('source.txt', 'destination.txt')  # Copy a file
# Out:
# 'destination.txt'

# %%
shutil.move('source.txt', 'new_directory/source1.txt')  # Move a file
# Out:
# 'new_directory/source1.txt'

# %%
## Data serialisation and deserialization
import json

data = {'name': 'Alice', 'age': 30, 'city': 'New York'}
# Serialize to JSON string  
json_string = json.dumps(data)
print(json_string)
print(type(json_string))  # <class 'str'>
print(type(data))  # <class 'dict'>
# Out:
# {"name": "Alice", "age": 30, "city": "New York"}
# <class 'str'>
# <class 'dict'>

# %%
json.loads(json_string)  # Deserialize back to Python object
# Out:
# {'name': 'Alice', 'age': 30, 'city': 'New York'}

# %%
### csv
import csv
with open('example.csv', 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(['Name', 'Age', 'City'])
    writer.writerow(['Alice', 30, 'New York'])
    writer.writerow(['Bob', 25, 'Los Angeles'])

with open('example.csv', 'r') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age', 'City']
# ['Alice', '30', 'New York']
# ['Bob', '25', 'Los Angeles']

# %%
import time
print(time.time())  # Current time in seconds since the epoch
time.sleep(2)  # Sleep for 2 seconds
print("Awake!")
print(time.strftime("%Y-%m-%d %H:%M:%S", time.localtime()))  # Current local time
# Out:
# 1789204023.638719
# Awake!
# 2026-09-12 14:37:05

# %%
 with open('example.csv', 'r') as file:
    for line in file:
        print(line.strip())  # Print each line without extra newline characters
# Out:
# Name,Age,City
# Alice,30,New York
# Bob,25,Los Angeles

# %%
with open('example.txt', 'w') as file:
    file.write("Hello, World!\n")
    file.write("This is a test file.\n")

# %%
with open('example.txt', 'a') as txtFile:
    txtFile.write("This is a new line.\n") ## to append a new line to the file
with open('example.txt', 'r') as txtFile:
    for line in txtFile:
        print(line.strip())  # Print each line without extra newline characters
# Out:
# Hello, World!
# This is a test file.
# This is a new line.
# This is a new line.
