# %% [markdown]
# ## Todo List

# %%
todo_lst= ["Buy Groc","Coffee Time","Gaming"]

## Adding to task:

todo_lst.append("Scheduling Sessions")
todo_lst.append("Live Comp Sessions")

## Removing 
todo_lst.remove("Gaming")

if "Coffee Time" in todo_lst:
    print("Dont forget to pay bills")

print("To do List remaining")
for task in todo_lst:
    print(f"-{task}")
# Out:
# Dont forget to pay bills
# To do List remaining
# -Buy Groc
# -Coffee Time
# -Scheduling Sessions
# -Live Comp Sessions

# %% [markdown]
# ## Orgranising Student Grades

# %%
feedback = ["Great Work","Very Satisfied","Could be better","Excellent Experience"]

## Adding new FeedBack

positive_feedback_count = sum(1 for comment in feedback if "great" in comment.lower() or "excellent" in comment.lower() or "satisfied" in comment.lower())
print(f"Positive Feedback Count:{positive_feedback_count}") 

## print all feedback

print("User Feedbacks --")
for comment in feedback:
    print(f"- {comment}")
# Out:
# Positive Feedback Count:3
# User Feedbacks --
# - Great Work
# - Very Satisfied
# - Could be better
# - Excellent Experience
