# %%
Name = "Abhishek"
name = "harshit"

print(Name)
print(name)
# Out:
# Abhishek
# harshit

# %% [markdown]
# ## Indentation
# ## Python uses indentation to define blocks of code

# %%
age = 32
if age<30:
    print(age)
else :
    print(2)

print("hello")
# Out:
# 2
# hello

# %%
total = 1+2+3+4+5+6+7+ \
4+5+6
print(total)
# Out:
# 43

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
## Type inference
variable =10;
print(type(variable))
variable="harsh"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
a=2
b=2

# %%
print(a==b)
a=3
b="3"
print(a==b)
# Out:
# True
# False
