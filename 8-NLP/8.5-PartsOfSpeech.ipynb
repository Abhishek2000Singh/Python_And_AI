# %%
## SPeech of Dr APJ ABDUL KALAM
paragraph= """
Good morning to everyone.
Today, I would like to speak about the importance of dreams, education, and hard work. A dream is not just something that we see when we are asleep. It is something that gives us the courage to work for a better future.We should always have a dream, and we should work hard to achieve it. In life, there will be many challenges, but we must not be afraid of them. With determination and confidence, we can overcome the difficulties that come in our way.
Education is one of the most powerful tools in the world. It gives us knowledge, and it helps us to understand the world around us. The young people of our country have the power to bring great changes to society.
We must believe in ourselves and in our abilities. We should use our knowledge for the development of our nation and for the benefit of others. If we work together with honesty, discipline, and dedication, we can make our country stronger and better.So, let us dream big, let us learn every day, and let us work with courage and determination. The future is in our hands, and it is our responsibility to make it bright.
Thank you.
"""

# %%
from nltk.corpus import stopwords
nltk.download('averaged_perceptron_tagger')
nltk.download('averaged_perceptron_tagger_eng')
sentences = nltk.sent_tokenize(paragraph)
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping taggers\averaged_perceptron_tagger_eng.zip.

# %%
sentences
# Out:
# ['\nGood morning to everyone.',
#  'Today, I would like to speak about the importance of dreams, education, and hard work.',
#  'A dream is not just something that we see when we are asleep.',
#  'It is something that gives us the courage to work for a better future.We should always have a dream, and we should work hard to achieve it.',
#  'In life, there will be many challenges, but we must not be afraid of them.',
#  'With determination and confidence, we can overcome the difficulties that come in our way.',
#  'Education is one of the most powerful tools in the world.',
#  'It gives us knowledge, and it helps us to understand the world around us.',
#  'The young people of our country have the power to bring great changes to society.',
#  'We must believe in ourselves and in our abilities.',
#  'We should use our knowledge for the development of our nation and for the benefit of others.',
# ...

# %%
## We will find out the POS tag

for i in range(len(sentences)):
    words = nltk.word_tokenize(sentences[i])
    words = [word for word in words if word not in set(stopwords.words('english'))]
    pos_tag = nltk.pos_tag(words)
    print(pos_tag)
# Out:
# [('Good', 'JJ'), ('morning', 'NN'), ('everyone', 'NN'), ('.', '.')]
# [('Today', 'NN'), (',', ','), ('I', 'PRP'), ('would', 'MD'), ('like', 'VB'), ('speak', 'JJ'), ('importance', 'NN'), ('dreams', 'NNS'), (',', ','), ('education', 'NN'), (',', ','), ('hard', 'JJ'), ('work', 'NN'), ('.', '.')]
# [('A', 'DT'), ('dream', 'NN'), ('something', 'NN'), ('see', 'VBP'), ('asleep', 'RB'), ('.', '.')]
# [('It', 'PRP'), ('something', 'NN'), ('gives', 'VBZ'), ('us', 'PRP'), ('courage', 'NN'), ('work', 'NN'), ('better', 'RBR'), ('future.We', 'NN'), ('always', 'RB'), ('dream', 'NN'), (',', ','), ('work', 'VB'), ('hard', 'RB'), ('achieve', 'NN'), ('.', '.')]
# [('In', 'IN'), ('life', 'NN'), (',', ','), ('many', 'JJ'), ('challenges', 'NNS'), (',', ','), ('must', 'MD'), ('afraid', 'VB'), ('.', '.')]
# [('With', 'IN'), ('determination', 'NN'), ('confidence', 'NN'), (',', ','), ('overcome', 'JJ'), ('difficulties', 'NNS'), ('come', 'VBP'), ('way', 'NN'), ('.', '.')]
# ...

# %%
## nltk.pos_tag("Taj Mahal is a beautiful Monument") wrong ways of doing this

# %%
import nltk

sentence = "Taj Mahal is a beautiful Monument"
words = nltk.word_tokenize(sentence)
pos_tags = nltk.pos_tag(words)
print(pos_tags)
# Out:
# [('Taj', 'NNP'), ('Mahal', 'NNP'), ('is', 'VBZ'), ('a', 'DT'), ('beautiful', 'JJ'), ('Monument', 'NN')]
