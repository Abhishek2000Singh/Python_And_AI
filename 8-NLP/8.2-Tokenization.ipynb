# %%
print(2)
# Out:
# 2

# %%
corpus = """Hello Welcome, to Abhishek's machine leaning Course.
Please take the course seriously! to become an expert."""
print(corpus)
# Out:
# Hello Welcome, to Abhishek's machine leaning Course.
# Please take the course seriously! to become an expert.

# %%
## Tokenization 
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
from nltk.tokenize import sent_tokenize

# %%
document = sent_tokenize(corpus)

# %%
type(document)
# Out:
# list

# %%
for sentence in document:
    print(sentence)
# Out:
# Hello Welcome, to Abhishek's machine leaning Course.
# Please take the course seriously!
# to become an expert

# %%
## Tokenization 
## Convert a para in words or sentence in words
from nltk.tokenize import word_tokenize

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Abhishek',
#  "'s",
#  'machine',
#  'leaning',
#  'Course',
#  '.',
#  'Please',
#  'take',
#  'the',
#  'course',
#  'seriously',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert']

# %%
for sentences in document:
    print(word_tokenize(sentences))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Abhishek', "'s", 'machine', 'leaning', 'Course', '.']
# ['Please', 'take', 'the', 'course', 'seriously', '!']
# ['to', 'become', 'an', 'expert']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Abhishek',
#  "'",
#  's',
#  'machine',
#  'leaning',
#  'Course',
#  '.',
#  'Please',
#  'take',
#  'the',
#  'course',
#  'seriously',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert']

# %%
for sentences in document:
    print(wordpunct_tokenize(sentences))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Abhishek', "'", 's', 'machine', 'leaning', 'Course', '.']
# ['Please', 'take', 'the', 'course', 'seriously', '!']
# ['to', 'become', 'an', 'expert']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer = TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Abhishek',
#  "'s",
#  'machine',
#  'leaning',
#  'Course.',
#  'Please',
#  'take',
#  'the',
#  'course',
#  'seriously',
#  '!',
#  'to',
#  'become',
#  'an',
#  'expert',
#  '.']
