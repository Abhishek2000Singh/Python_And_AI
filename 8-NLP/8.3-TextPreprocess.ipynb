# %%
## Stemming is process of reducing a word to its word stem that that affixes to suffixes and prefixes or to the root if words known as lemma 

## Classification Probelm 
## Comment of Product is a positive or negative review
## Reviews --->  eating, eat, eaten here EAT is stem word or root word which will not impact much which is basically talking about EAT, each words represent vector--> eat

# %%
words = ["eating","eats","eaten","writing","writes","programming","pragrams","history","finalized","finally"]

# %% [markdown]
# ## Porter Stemmer

# %%
from nltk.stem import PorterStemmer

# %%
stemming = PorterStemmer()

# %%
for word in words:
    print(word+"--->"+stemming.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# pragrams--->pragram
# history--->histori
# finalized--->final
# finally--->final

# %%
stemming.stem('congratulations') ## there is major disadvantage as it changes meaning most of the times
# Out:
# 'congratul'

# %%
## RegexpStemmer Class for regular Expression

# %%
from nltk.stem import RegexpStemmer

# %%
reg_stemmer = RegexpStemmer('ing$|s$|e$|able$', min=4)

# %%
reg_stemmer.stem('eating')
# Out:
# 'eating'

# %%
reg_stemmer.stem('readable')
# Out:
# 'read'

# %% [markdown]
# ## Snowball Stemmer

# %%
## better accuracy 
from nltk.stem import SnowballStemmer

# %%
snow_ball = SnowballStemmer('english')

# %%
for word in words:
    print(word+'--->'+snow_ball.stem(word))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eaten
# writing--->write
# writes--->write
# programming--->program
# pragrams--->pragram
# history--->histori
# finalized--->final
# finally--->final

# %%
stemming.stem('fairly'),stemming.stem('sportingly')
# Out:
# ('fairli', 'sportingli')

# %%
snow_ball.stem('fairly'),snow_ball.stem('sportingly')
# Out:
# ('fair', 'sport')

# %%
snow_ball.stem('goes'), stemming.stem('goes')
# Out:
# ('goe', 'goe')

# %% [markdown]
# ## Wordnet Lemmetizer

# %% [markdown]
# * Lemmatization is technique like stemming . The output will get after this is called lemma which is a root word rather than root stem

# %%
import nltk 
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.stem import WordNetLemmatizer
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\LENOVO\AppData\Roaming\nltk_data...

# %%
lemmatizer = WordNetLemmatizer()
'''
POS - Noun -n
verb -v
adjective- a
adverb -r
'''

# %%
lemmatizer.lemmatize("going", pos='v')
# Out:
# 'go'

# %%
for word in words:
    print(word+'--->'+lemmatizer.lemmatize(word,pos='v'))
# Out:
# eating--->eat
# eats--->eat
# eaten--->eat
# writing--->write
# writes--->write
# programming--->program
# pragrams--->pragrams
# history--->history
# finalized--->finalize
# finally--->finally

# %%
lemmatizer.lemmatize('goes',pos='v'),lemmatizer.lemmatize('fairly',pos='v')
# Out:
# ('go', 'fairly')

# %%
# Out:
# 2
